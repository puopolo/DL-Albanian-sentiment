# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
file_path = '/content/drive/My Drive/Colab Notebooks/dl-albanian/AlbAna-simplified.csv'

# Load the CSV file into a DataFrame
df = pd.read_csv(file_path, header=0)

# %%
#Create lists of Annotations and Comments
y = df['Annotation']
docs = df['Comment']

# %%
# !pip install nlu==5.1.2
# !pip install pyspark==3.4.1
# !pip install spark-nlp==5.0.2
# Out:
# Requirement already satisfied: nlu==5.1.2 in /usr/local/lib/python3.10/dist-packages (5.1.2)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.10/dist-packages (from nlu==5.1.2) (0.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from nlu==5.1.2) (1.25.2)
# Requirement already satisfied: pandas>=1.3.5 in /usr/local/lib/python3.10/dist-packages (from nlu==5.1.2) (1.5.3)
# Requirement already satisfied: pyarrow>=0.16.0 in /usr/local/lib/python3.10/dist-packages (from nlu==5.1.2) (14.0.2)
# Requirement already satisfied: spark-nlp>=5.0.2 in /usr/local/lib/python3.10/dist-packages (from nlu==5.1.2) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->nlu==5.1.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->nlu==5.1.2) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.3.5->nlu==5.1.2) (1.16.0)
# Collecting pyspark==3.4.1
#   Downloading pyspark-3.4.1.tar.gz (310.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark==3.4.1) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.4.1-py2.py3-none-any.whl size=311285388 sha256=aa74b6fdb5d99fe3236e3a6ccfda15213db4bbf26f0fd859977e9e75394f2ffd
#   Stored in directory: /root/.cache/pip/wheels/0d/77/a3/ff2f74cc9ab41f8f594dabf0579c2a7c6de920d584206e0834
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.4.1
# Requirement already satisfied: spark-nlp==5.0.2 in /usr/local/lib/python3.10/dist-packages (5.0.2)

# %%
# Remove stop words

import pyspark
import sparknlp
from sparknlp.annotator import DocumentAssembler, Tokenizer, StopWordsCleaner
from pyspark.sql.functions import udf
from pyspark.sql.types import ArrayType, StringType
from pyspark.ml import Pipeline
spark = sparknlp.start()


# Create a Spark DataFrame containing text data
df = spark.createDataFrame([(text,) for text in docs], ["text"])

documentAssembler = DocumentAssembler() \
.setInputCol("text") \
.setOutputCol("document")

tokenizer = Tokenizer() \
.setInputCols(["document"]) \
.setOutputCol("token")

stop_words = StopWordsCleaner.pretrained("stopwords_iso","sq") \
.setInputCols(["token"]) \
.setOutputCol("cleanTokens")

pipeline = Pipeline(stages=[documentAssembler, tokenizer, stop_words])


# Define pipeline
pipeline = Pipeline(stages=[documentAssembler, tokenizer, stop_words])

# Fitting the pipeline on Spark DataFrame to transform the text data
results = pipeline.fit(df).transform(df)
results.show(truncate=False)
# Out:
# stopwords_iso download started this may take some time.
# Approximate size to download 1.9 KB
# [OK!]
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ ...
# |text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |document                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |token                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ ...
# |Dorentina TBT                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |[{document, 0, 13, Dorentina TBT , {sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |[{token, 0, 8, Dorentina, {sentence -> 0}, []}, {token, 10, 12, TBT, {sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# |Mbyllni kufijte sot. Sitiata ka me u ba shume keq.                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |[{document, 0, 49, Mbyllni kufijte sot. Sitiata ka me u ba shume keq., {sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |[{token, 0, 6, Mbyllni, {sentence -> 0}, []}, {token, 8, 14, kufijte, {sentence -> 0}, []}, {token, 16, 18, sot, {sentence -> 0}, []}, {token, 19, 19, ., {sentence -> 0}, []}, {token, 21, 27, Sitiata, {sentence -> 0}, []}, {token, 29, 30, ka, {sentence -> 0}, []}, {token, 32, 33, me, {sentence -> 0}, []}, {token, 35, 35, u, {sentence -> 0}, []}, {token, 37, 38, ba, {sentence -> 0}, []}, {token, 40, 44, shume, {sentence -> 0}, []}, {token, 46, 48, keq, {sentence -> 0}, []}, {token, 49, 49, ., {sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# |Mbyllni kufit ashtu mund te jemi te sigurte, perndryshe skemi shpetim jemi te rrethuar !                                                                                                                                                                                                                                                                                                                                                                                                                                |[{document, 0, 87, Mbyllni kufit ashtu mund te jemi te sigurte, perndryshe skemi shpetim jemi te rrethuar !, {sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                                                                                                                 |[{token, 0, 6, Mbyllni, {sentence -> 0}, []}, {token, 8, 12, kufit, {sentence -> 0}, []}, {token, 14, 18, ashtu, {sentence -> 0}, []}, {token, 20, 23, mund, {sentence -> 0}, []}, {token, 25, 26, te, {sentence -> 0}, []}, {token, 28, 31, jemi, {sentence -> 0}, []}, {token, 33, 34, te, {sentence -> 0}, []}, {token, 36, 42, sigurte, {sentence -> 0}, []}, {token, 43, 43, ,, {sentence -> 0}, []}, {token, 45, 54, perndryshe, {sentence -> 0}, []}, {token, 56, 60, skemi, {sentence -> 0}, []}, {token, 62, 68, shpetim, {sentence -> 0}, []}, {token, 70, 73, jemi, {sentence -> 0}, []}, {token, 75, 76, te, {sentence -> 0}, []}, {token, 78, 85, rrethuar, {sentence -> 0}, []}, {token, 87, 87, !, {sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# |Pse nuk po  i  mbyllni  kufijte,  sonte  ne  qytete pat   plot  makina  me  targa  te  zvicres  qe  kane  ardh, ata  duhen  me  wendru  ne  karantine  shtepiake,  por  jo  ,  ata  i  ke  neper  kafeteri...  keshtuqe per  disa  dite  pritemi  covid  19  edhe  ne  ks,  fal  kufinjeve  qe  jan  free  entry                                                                                                                                                                                                        |[{document, 0, 303, Pse nuk po  i  mbyllni  kufijte,  sonte  ne  qytete pat   plot  makina  me  targa  te  zvicres  qe  kane  ardh, ata  duhen  me  wendru  ne  karantine  shtepiake,  por  jo  ,  ata  i  ke  neper  kafeteri...  keshtuqe per  disa  dite  pritemi  covid  19  edhe  ne  ks,  fal  kufinjeve  qe  jan  free  entry, {sentence -> 0}, []}]                                                                                                                                                                                                        |[{token, 0, 2, Pse, {sentence -> 0}, []}, {token, 4, 6, nuk, {sentence -> 0}, []}, {token, 8, 9, po, {sentence -> 0}, []}, {token, 12, 12, i, {sentence -> 0}, []}, {token, 15, 21, mbyllni, {sentence -> 0}, []}, {token, 24, 30, kufijte, {sentence -> 0}, []}, {token, 31, 31, ,, {sentence -> 0}, []}, {token, 34, 38, sonte, {sentence -> 0}, []}, {token, 41, 42, ne, {sentence -> 0}, []}, {token, 45, 50, qytete, {sentence -> 0}, []}, {token, 52, 54, pat, {sentence -> 0}, []}, {token, 58, 61, plot, {sentence -> 0}, []}, {token, 64, 69, makina, {sentence -> 0}, []}, {token, 72, 73, me, {sentence -> 0}, []}, {token, 76, 80, targa, {sentence -> 0}, []}, {token, 83, 84, te, {sentence -> 0}, []}, {token, 87, 93, zvicres, {sentence -> 0}, []}, {token, 96, 97, qe, {sentence -> 0}, []}, {token, 100, 103, kane, {sentence -> 0}, []}, {token, 106, 109, ardh, {sentence -> 0}, []}, {token, 110, 110, ,, {sentence -> 0}, []}, {token, 112, 114, ata, {sentence -> 0}, []}, {token, 117, 121, duhen, {sentence -> 0}, []}, {token, 124, 125, me, {sentence -> 0}, []}, {token, 128, 133, wendru, {sentence -> 0}, []}, {token, 136, 137, ne, {sentence -> 0}, []}, {token, 140, 148, karantine, {sentence -> 0}, []}, {token, 151, 159, shtepiake, {sentence -> 0}, []}, {token, 160, 160, ,, {sentence -> 0}, []}, {token, 163, 165, por, {sentence -> 0}, []}, {token, 168, 169, jo, {sentence -> 0}, []}, {token, 172, 172, ,, {sentence -> 0}, []}, {token, 175, 177, ata, {sentence -> 0}, []}, {token, 180, 180, i, {sentence -> 0}, []}, {token, 183, 184, ke, {sentence -> 0}, []}, {token, 187, 191, neper, {sentence -> 0}, []}, {token, 194, 201, kafeteri, {sentence -> 0}, []}, {token, 202, 204, ..., {sentence -> 0}, []}, {token, 207, 214, keshtuqe, {sentence -> 0}, []}, {token, 216, 218, per, {sentence -> 0}, []}, {token, 221, 224, disa, {sentence -> 0}, []}, {token, 227, 230, dite, {sentence -> 0}, []}, {token, 233, 239, pritemi, {sentence -> 0}, []}, {token, 242, 246, covid, {sentence -> 0}, []}, {token, 249, 250, 19, {sentence -> 0}, []}, {token, 253, 256, edhe, {sentence -> 0}, []}, {token, 259, 260, ne, {sentence -> 0}, []}, {token, 263, 264, ks, {sentence -> 0}, []}, {token, 265, 265, ,, {sentence -> 0}, []}, {token, 268, 270, fal, {sentence -> 0}, []}, {token, 273, 281, kufinjeve, {sentence -> 0}, []}, {token, 284, 285, qe, {sentence -> 0}, []}, {token, 288, 290, jan, {sentence -> 0}, []}, {token, 293, 296, free, {sentence -> 0}, []}, {token, 299, 303, entry, {sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# |Mos  harroni  qe  kufinjte  tane  jane  te  hapur,  po  kalojne  vazhdimisht  njerez, dhe  ju  e  dini  we  vetem  me  matje  te  temperatures  nuk  identifikohen  personat  e  infektuar,..                                                                                                                                                                                                                                                                                                                           |[{document, 0, 190, Mos  harroni  qe  kufinjte  tane  jane  te  hapur,  po  kalojne  vazhdimisht  njerez, dhe  ju  e  dini  we  vetem  me  matje  te  temperatures  nuk  identifikohen  personat  e  infektuar,..  , {sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                         |[{token, 0, 2, Mos, {sentence -> 0}, []}, {token, 5, 11, harroni, {sentence -> 0}, []}, {token, 14, 15, qe, {sentence -> 0}, []}, {token, 18, 25, kufinjte, {sentence -> 0}, []}, {token, 28, 31, tane, {sentence -> 0}, []}, {token, 34, 37, jane, {sentence -> 0}, []}, {token, 40, 41, te, {sentence -> 0}, []}, {token, 44, 48, hapur, {sentence -> 0}, []}, {token, 49, 49, ,, {sentence -> 0}, []}, {token, 52, 53, po, {sentence -> 0}, []}, {token, 56, 62, kalojne, {sentence -> 0}, []}, {token, 65, 75, vazhdimisht, {sentence -> 0}, []}, {token, 78, 83, njerez, {sentence -> 0}, []}, {token, 84, 84, ,, {sentence -> 0}, []}, {token, 86, 88, dhe, {sentence -> 0}, []}, {token, 91, 92, ju, {sentence -> 0}, []}, {token, 95, 95, e, {sentence -> 0}, []}, {token, 98, 101, dini, {sentence -> 0}, []}, {token, 104, 105, we, {sentence -> 0}, []}, {token, 108, 112, vetem, {sentence -> 0}, []}, {token, 115, 116, me, {sentence -> 0}, []}, {token, 119, 123, matje, {sentence -> 0}, []}, {token, 126, 127, te, {sentence -> 0}, []}, {token, 130, 141, temperatures, {sentence -> 0}, []}, {token, 144, 146, nuk, {sentence -> 0}, []}, {token, 149, 161, identifikohen, {sentence -> 0}, []}, {token, 164, 171, personat, {sentence -> 0}, []}, {token, 174, 174, e, {sentence -> 0}, []}, {token, 177, 185, infektuar, {sentence -> 0}, []}, {token, 186, 188, ,.., {sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# |Flm per njoftimet e vazhdueshme. A i kontrollini secilin udhetar qe vie ne aeroport nga Evropa ?                                                                                                                                                                                                                                                                                                                                                                                                                        |[{document, 0, 95, Flm per njoftimet e vazhdueshme. A i kontrollini secilin udhetar qe vie ne aeroport nga Evropa ?, {sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                                                                                                         |[{token, 0, 2, Flm, {sentence -> 0}, []}, {token, 4, 6, per, {sentence -> 0}, []}, {token, 8, 16, njoftimet, {sentence -> 0}, []}, {token, 18, 18, e, {sentence -> 0}, []}, {token, 20, 30, vazhdueshme, {sentence -> 0}, []}, {token, 31, 31, ., {sentence -> 0}, []}, {token, 33, 33, A, {sentence -> 0}, []}, {token, 35, 35, i, {sentence -> 0}, []}, {token, 37, 47, kontrollini, {sentence -> 0}, []}, {token, 49, 55, secilin, {sentence -> 0}, []}, {token, 57, 63, udhetar, {sentence -> 0}, []}, {token, 65, 66, qe, {sentence -> 0}, []}, {token, 68, 70, vie, {sentence -> 0}, []}, {token, 72, 73, ne, {sentence -> 0}, []}, {token, 75, 82, aeroport, {sentence -> 0}, []}, {token, 84, 86, nga, {sentence -> 0}, []}, {token, 88, 93, Evropa, {sentence -> 0}, []}, {token, 95, 95, ?, {sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# |Mbyllni kufinjt mos luani me jetet e njerzve, me mire te parandalohet se sa te mos sherohet. Gjermania Italia etj etj Ku jemi ne!!!                                                                                                                                                                                                                                                                                                                                                                                     |[{document, 0, 130, Mbyllni kufinjt mos luani me jetet e njerzve, me mire te parandalohet se sa te mos sherohet. Gjermania Italia etj etj Ku jemi ne!!!, {sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                                                                     |[{token, 0, 6, Mbyllni, {sentence -> 0}, []}, {token, 8, 14, kufinjt, {sentence -> 0}, []}, {token, 16, 18, mos, {sentence -> 0}, []}, {token, 20, 24, luani, {sentence -> 0}, []}, {token, 26, 27, me, {sentence -> 0}, []}, {token, 29, 33, jetet, {sentence -> 0}, []}, {token, 35, 35, e, {sentence -> 0}, []}, {token, 37, 43, njerzve, {sentence -> 0}, []}, {token, 44, 44, ,, {sentence -> 0}, []}, {token, 46, 47, me, {sentence -> 0}, []}, {token, 49, 52, mire, {sentence -> 0}, []}, {token, 54, 55, te, {sentence -> 0}, []}, {token, 57, 68, parandalohet, {sentence -> 0}, []}, {token, 70, 71, se, {sentence -> 0}, []}, {token, 73, 74, sa, {sentence -> 0}, []}, {token, 76, 77, te, {sentence -> 0}, []}, {token, 79, 81, mos, {sentence -> 0}, []}, {token, 83, 90, sherohet, {sentence -> 0}, []}, {token, 91, 91, ., {sentence -> 0}, []}, {token, 93, 101, Gjermania, {sentence -> 0}, []}, {token, 103, 108, Italia, {sentence -> 0}, []}, {token, 110, 112, etj, {sentence -> 0}, []}, {token, 114, 116, etj, {sentence -> 0}, []}, {token, 118, 119, Ku, {sentence -> 0}, []}, {token, 121, 124, jemi, {sentence -> 0}, []}, {token, 126, 127, ne, {sentence -> 0}, []}, {token, 128, 130, !!!, {sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# |Arilë Ramushi                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |[{document, 0, 13, Arilë Ramushi , {sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |[{token, 0, 4, Arilë, {sentence -> 0}, []}, {token, 6, 12, Ramushi, {sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# ...
# |Idiotizmi ma i madhi qe kam parë në jetë është se vetura të italis dhe shqipëris ka në mas të madhe në Kosovë ,sikur pak me mendu qeveria kishte me vepru shumë heret mirpo jan të nxanun me poste ishalla ka hunda ju dalin të paskrupuj ,Kosova qe 20 vjet nuk ka drejt me kalu kufijt e bash per coronavirus po i leni kufijt e hapur ,edhe kufiri me shqiperi pse nuk mbyllet qka na duhen te huajt kur ne vendin e tyre të poshtrojnë ,ju gjith politikanet thirreni vetem pak at tru nese ka mbet diqka në të ....|[{document, 0, 503, Idiotizmi ma i madhi qe kam parë në jetë është se vetura të italis dhe shqipëris ka në mas të madhe në Kosovë ,sikur pak me mendu qeveria kishte me vepru shumë heret mirpo jan të nxanun me poste ishalla ka hunda ju dalin të paskrupuj ,Kosova qe 20 vjet nuk ka drejt me kalu kufijt e bash per coronavirus po i leni kufijt e hapur ,edhe kufiri me shqiperi pse nuk mbyllet qka na duhen te huajt kur ne vendin e tyre të poshtrojnë ,ju gjith politikanet thirreni vetem pak at tru nese ka mbet diqka në të ...., {sentence -> 0}, []}]|[{token, 0, 8, Idiotizmi, {sentence -> 0}, []}, {token, 10, 11, ma, {sentence -> 0}, []}, {token, 13, 13, i, {sentence -> 0}, []}, {token, 15, 19, madhi, {sentence -> 0}, []}, {token, 21, 22, qe, {sentence -> 0}, []}, {token, 24, 26, kam, {sentence -> 0}, []}, {token, 28, 31, parë, {sentence -> 0}, []}, {token, 33, 34, në, {sentence -> 0}, []}, {token, 36, 39, jetë, {sentence -> 0}, []}, {token, 41, 45, është, {sentence -> 0}, []}, {token, 47, 48, se, {sentence -> 0}, []}, {token, 50, 55, vetura, {sentence -> 0}, []}, {token, 57, 58, të, {sentence -> 0}, []}, {token, 60, 65, italis, {sentence -> 0}, []}, {token, 67, 69, dhe, {sentence -> 0}, []}, {token, 71, 79, shqipëris, {sentence -> 0}, []}, {token, 81, 82, ka, {sentence -> 0}, []}, {token, 84, 85, në, {sentence -> 0}, []}, {token, 87, 89, mas, {sentence -> 0}, []}, {token, 91, 92, të, {sentence -> 0}, []}, {token, 94, 98, madhe, {sentence -> 0}, []}, {token, 100, 101, në, {sentence -> 0}, []}, {token, 103, 108, Kosovë, {sentence -> 0}, []}, {token, 110, 110, ,, {sentence -> 0}, []}, {token, 111, 115, sikur, {sentence -> 0}, []}, {token, 117, 119, pak, {sentence -> 0}, []}, {token, 121, 122, me, {sentence -> 0}, []}, {token, 124, 128, mendu, {sentence -> 0}, []}, {token, 130, 136, qeveria, {sentence -> 0}, []}, {token, 138, 143, kishte, {sentence -> 0}, []}, {token, 145, 146, me, {sentence -> 0}, []}, {token, 148, 152, vepru, {sentence -> 0}, []}, {token, 154, 158, shumë, {sentence -> 0}, []}, {token, 160, 164, heret, {sentence -> 0}, []}, {token, 166, 170, mirpo, {sentence -> 0}, []}, {token, 172, 174, jan, {sentence -> 0}, []}, {token, 176, 177, të, {sentence -> 0}, []}, {token, 179, 184, nxanun, {sentence -> 0}, []}, {token, 186, 187, me, {sentence -> 0}, []}, {token, 189, 193, poste, {sentence -> 0}, []}, {token, 195, 201, ishalla, {sentence -> 0}, []}, {token, 203, 204, ka, {sentence -> 0}, []}, {token, 206, 210, hunda, {sentence -> 0}, []}, {token, 212, 213, ju, {sentence -> 0}, []}, {token, 215, 219, dalin, {sentence -> 0}, []}, {token, 221, 222, të, {sentence -> 0}, []}, {token, 224, 232, paskrupuj, {sentence -> 0}, []}, {token, 234, 234, ,, {sentence -> 0}, []}, {token, 235, 240, Kosova, {sentence -> 0}, []}, {token, 242, 243, qe, {sentence -> 0}, []}, {token, 245, 246, 20, {sentence -> 0}, []}, {token, 248, 251, vjet, {sentence -> 0}, []}, {token, 253, 255, nuk, {sentence -> 0}, []}, {token, 257, 258, ka, {sentence -> 0}, []}, {token, 260, 264, drejt, {sentence -> 0}, []}, {token, 266, 267, me, {sentence -> 0}, []}, {token, 269, 272, kalu, {sentence -> 0}, []}, {token, 274, 279, kufijt, {sentence -> 0}, []}, {token, 281, 281, e, {sentence -> 0}, []}, {token, 283, 286, bash, {sentence -> 0}, []}, {token, 288, 290, per, {sentence -> 0}, []}, {token, 292, 302, coronavirus, {sentence -> 0}, []}, {token, 304, 305, po, {sentence -> 0}, []}, {token, 307, 307, i, {sentence -> 0}, []}, {token, 309, 312, leni, {sentence -> 0}, []}, {token,  ...
# |Mbani te paster telefonat gjithashtu                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |[{document, 0, 35, Mbani te paster telefonat gjithashtu, {sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |[{token, 0, 4, Mbani, {sentence -> 0}, []}, {token, 6, 7, te, {sentence -> 0}, []}, {token, 9, 14, paster, {sentence -> 0}, []}, {token, 16, 24, telefonat, {sentence -> 0}, []}, {token, 26, 35, gjithashtu, {sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ ...
# only showing top 20 rows

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split

# %%
# Train-test split
x_train, x_test, y_train, y_test = train_test_split(docs, y, test_size=0.3, random_state=1000)

# %%
# Tokenization
from transformers import BertTokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')
train_inputs = tokenizer(x_train.tolist(), padding=True, truncation=True, return_tensors="pt")
test_inputs = tokenizer(x_test.tolist(), padding=True, truncation=True, return_tensors="pt")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]

# %%
# Model: mBERT
from transformers import BertForSequenceClassification
num_labels = len(y.unique())
model = BertForSequenceClassification.from_pretrained('bert-base-multilingual-cased', num_labels=num_labels)
# Out:
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Fine-tuning parameters
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-5)

# %%
# Convert labels to tensor
train_labels = torch.tensor(y_train.tolist())
test_labels = torch.tensor(y_test.tolist())

# %%
# Create DataLoader for training and testing
train_dataset = TensorDataset(train_inputs.input_ids, train_inputs.attention_mask, train_labels)
test_dataset = TensorDataset(test_inputs.input_ids, test_inputs.attention_mask, test_labels)

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)

# %%
# Fine-tuning
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

model.train()
for epoch in range(3):  # can adjust the number of epochs here
    total_loss = 0
    for batch in train_loader:
        input_ids, attention_mask, labels = batch
        input_ids, attention_mask, labels = input_ids.to(device), attention_mask.to(device), labels.to(device)

        optimizer.zero_grad()

        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        total_loss += loss.item()

        loss.backward()
        optimizer.step()

    print(f"Epoch {epoch+1}, Average Loss: {total_loss/len(train_loader)}")

# Save the fine-tuned model
model.save_pretrained("/content/drive/My Drive/Colab Notebooks/dl-albanian/xlm-model")
# Out:
# Epoch 1, Average Loss: 0.7830200090687326
# Epoch 2, Average Loss: 0.5957988626779394
# Epoch 3, Average Loss: 0.45994954155956175

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.figure(figsize=(10, 8))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import itertools

# Set model to evaluation mode
model.eval()

# Initialize lists to store predictions and true labels
all_preds = []
all_labels = []

# Iterate over the test loader
for batch in test_loader:
    input_ids, attention_mask, labels = batch
    input_ids, attention_mask, labels = input_ids.to(device), attention_mask.to(device), labels.to(device)

    # Forward pass
    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask)
        logits = outputs.logits

    # Predictions
    preds = logits.argmax(dim=1)

    # Append predictions and true labels to lists
    all_preds.extend(preds.cpu().numpy())
    all_labels.extend(labels.cpu().numpy())

# accuracy
accuracy = accuracy_score(all_labels, all_preds)
print("Accuracy:", accuracy)

# other metrics
print(classification_report(all_labels, all_preds))

# confusion matrix
cnf_matrix = confusion_matrix(all_labels, all_preds)
classes = ['0', '1', '2']
plot_confusion_matrix(cnf_matrix, classes=classes)
# Out:
# Accuracy: 0.7300651566863171
#               precision    recall  f1-score   support
#
#            0       0.79      0.77      0.78      1837
#            1       0.86      0.60      0.70       507
#            2       0.59      0.71      0.64       879
#
#     accuracy                           0.73      3223
#    macro avg       0.74      0.69      0.71      3223
# weighted avg       0.75      0.73      0.73      3223
#
# Confusion matrix, without normalization
